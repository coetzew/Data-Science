# %% [markdown]
# ### IBM DATA SCIENCE CAPSTONE PROJECT

# %% [markdown]
# ## **Purpose:**
# * To learn to use Foursquare API to access location data.
# * To find neighbourhoods in East Toronto that are similar to a specified neighbourhood in West Toronto.
